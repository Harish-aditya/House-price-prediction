# %% [markdown]
# ### Importing important libraries for the project.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as sklearn

# %%
df = pd.read_csv('train-chennai-sale.csv')

# %%
df
# Out:
#       PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0     P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1     P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2     P01812       Adyar       909  04-02-2012             70        1.0
# 3     P05346   Velachery      1855  13-03-2010             14        3.0
# 4     P06210  Karapakkam      1226  05-10-2009             84        1.0
# ...      ...         ...       ...         ...            ...        ...
# 7104  P03834  Karapakkam       598  03-01-2011             51        1.0
# 7105  P10000   Velachery      1897  08-04-2004             52        3.0
# 7106  P09594   Velachery      1614  25-08-2006            152        2.0
# 7107  P06508  Karapakkam       787  03-08-2009             40        1.0
# 7108  P09794   Velachery      1896  13-07-2005            156        3.0
#
#       N_BATHROOM  N_ROOM    SALE_COND PARK_FACIL  ... UTILITY_AVAIL  \
# 0            1.0       3     AbNormal        Yes  ...        AllPub
# 1            1.0       5     AbNormal         No  ...        AllPub
# 2            1.0       3     AbNormal        Yes  ...           ELO
# 3            2.0       5       Family         No  ...       NoSewr
# 4            1.0       3     AbNormal        Yes  ...        AllPub
# ...          ...     ...          ...        ...  ...           ...
# 7104         1.0       2      AdjLand         No  ...           ELO
# 7105         2.0       5       Family        Yes  ...        NoSeWa
# 7106         1.0       4  Normal Sale         No  ...        NoSeWa
# 7107         1.0       2      Partial        Yes  ...           ELO
# 7108         2.0       5      Partial        Yes  ...           ELO
#
#          STREET MZZONE QS_ROOMS QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  \
# 0         Paved      A      4.0         3.9         4.9       4.330   380000
# 1        Gravel     RH      4.9         4.2         2.5       3.765   760122
# 2        Gravel     RL      4.1         3.8         2.2       3.090   421094
# 3         Paved      I      4.7         3.9         3.6       4.010   356321
# 4        Gravel      C      3.0         2.5         4.1       3.290   237000
# ...         ...    ...      ...         ...         ...         ...      ...
# 7104  No Access     RM      3.0         2.2         2.4       2.520   208767
# 7105  No Access     RH      3.6         4.5         3.3       3.920   346191
# 7106     Gravel      I      4.3         4.2         2.9       3.840   317354
# 7107      Paved     RL      4.6         3.8         4.1       4.160   425350
# 7108      Paved      I      3.1         3.5         4.3       3.640   349177
#
#       COMMIS  SALES_PRICE
# 0     144400      7600000
# 1     304049     21717770
# 2      92114     13159200
# 3      77042      9630290
# 4      74063      7406250
# ...      ...          ...
# 7104  107060      5353000
# 7105  205551     10818480
# 7106  167028      8351410
# 7107  119098      8507000
# 7108   79812      9976480
#
# [7109 rows x 22 columns]

# %% [markdown]
# ## Shape of the given dataset

# %%
df.shape
# Out:
# (7109, 22)

# %%
df.columns
# Out:
# Index(['PRT_ID', 'AREA', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE'],
#       dtype='object')

# %%
df.describe()
# Out:
#           INT_SQFT  DIST_MAINROAD    N_BEDROOM   N_BATHROOM       N_ROOM  \
# count  7109.000000    7109.000000  7108.000000  7104.000000  7109.000000
# mean   1382.073006      99.603179     1.637029     1.213260     3.688704
# std     457.410902      57.403110     0.802902     0.409639     1.019099
# min     500.000000       0.000000     1.000000     1.000000     2.000000
# 25%     993.000000      50.000000     1.000000     1.000000     3.000000
# 50%    1373.000000      99.000000     1.000000     1.000000     4.000000
# 75%    1744.000000     148.000000     2.000000     1.000000     4.000000
# max    2500.000000     200.000000     4.000000     2.000000     6.000000
#
#           QS_ROOMS  QS_BATHROOM   QS_BEDROOM   QS_OVERALL        REG_FEE  \
# count  7109.000000  7109.000000  7109.000000  7061.000000    7109.000000
# mean      3.517471     3.507244     3.485300     3.503254  376938.330708
# std       0.891972     0.897834     0.887266     0.527223  143070.662010
# min       2.000000     2.000000     2.000000     2.000000   71177.000000
# 25%       2.700000     2.700000     2.700000     3.130000  272406.000000
# 50%       3.500000     3.500000     3.500000     3.500000  349486.000000
# 75%       4.300000     4.300000     4.300000     3.890000  451562.000000
# max       5.000000     5.000000     5.000000     4.970000  983922.000000
#
#               COMMIS   SALES_PRICE
# count    7109.000000  7.109000e+03
# mean   141005.726544  1.089491e+07
# std     78768.093718  3.768603e+06
# min      5055.000000  2.156875e+06
# 25%     84219.000000  8.272100e+06
# 50%    127628.000000  1.033505e+07
# 75%    184506.000000  1.299390e+07
# max    495405.000000  2.366734e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRT_ID         7109 non-null   object
#  1   AREA           7109 non-null   object
#  2   INT_SQFT       7109 non-null   int64
#  3   DATE_SALE      7109 non-null   object
#  4   DIST_MAINROAD  7109 non-null   int64
#  5   N_BEDROOM      7108 non-null   float64
#  6   N_BATHROOM     7104 non-null   float64
#  7   N_ROOM         7109 non-null   int64
#  8   SALE_COND      7109 non-null   object
#  9   PARK_FACIL     7109 non-null   object
#  10  DATE_BUILD     7109 non-null   object
#  11  BUILDTYPE      7109 non-null   object
#  12  UTILITY_AVAIL  7109 non-null   object
#  13  STREET         7109 non-null   object
#  14  MZZONE         7109 non-null   object
#  15  QS_ROOMS       7109 non-null   float64
#  16  QS_BATHROOM    7109 non-null   float64
#  17  QS_BEDROOM     7109 non-null   float64
#  18  QS_OVERALL     7061 non-null   float64
#  19  REG_FEE        7109 non-null   int64
#  20  COMMIS         7109 non-null   int64
#  21  SALES_PRICE    7109 non-null   int64
# dtypes: float64(6), int64(6), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
# We can see from the info that there are no null values.

# %% [markdown]
# We can see that data set contains mix of categorical and numerical columns.

# %% [markdown]
# Let's explore Categorical Columns

# %% [markdown]
# ## AREA

# %%
df.AREA.nunique()
# Out:
# 17

# %%
df.AREA.unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KK Nagar', 'TNagar', 'T Nagar', 'Chrompt', 'Chrmpet', 'Karapakam',
#        'Ana Nagar', 'Chormpet', 'Adyr', 'Velchery', 'Ann Nagar',
#        'KKNagar'], dtype=object)

# %% [markdown]
# We can see that there are some spelling mistakes in the AREA column.

# %%
df.AREA.value_counts()
# Out:
# Chrompet      1681
# Karapakkam    1363
# KK Nagar       996
# Velachery      979
# Anna Nagar     783
# Adyar          773
# T Nagar        496
# Chrompt          9
# Chrmpet          6
# Chormpet         6
# TNagar           5
# Karapakam        3
# Ana Nagar        3
# Velchery         2
# Ann Nagar        2
# Adyr             1
# KKNagar          1
# Name: AREA, dtype: int64

# %%
df['AREA'] = df['AREA'].replace({'Adyr':'Adyar','Chrompt':'Chrompet','Chrmpet':'Chrompet','Chormpet':'Chrompet','TNagar':'T Nagar','Karapakam':'Karapakkam','Ana Nagar':'Anna Nagar','Ann Nagar':'Anna Nagar','Adyr':'Adyar','Velchery':'Velachery','KKNagar':'KK Nagar'})

# %%
df.AREA.value_counts()
# Out:
# Chrompet      1702
# Karapakkam    1366
# KK Nagar       997
# Velachery      981
# Anna Nagar     788
# Adyar          774
# T Nagar        501
# Name: AREA, dtype: int64

# %%
df.groupby('AREA')['SALES_PRICE'].mean().sort_values(ascending=True).plot.bar()
# Out:
# <AxesSubplot:xlabel='AREA'>

# %% [markdown]
# Here we can see that there is a linear relationship between AREA and SALE_PRICE with mean.

# %%
df.groupby('AREA')['SALES_PRICE'].sum().sort_values(ascending=True).plot.bar()
# Out:
# <AxesSubplot:xlabel='AREA'>

# %% [markdown]
# Here, we can see that there are more sales and total transaction was done in chrompet from the given dataset.

# %%
df.groupby('AREA')['SALES_PRICE'].count().sort_values(ascending=True).plot.bar()
# Out:
# <AxesSubplot:xlabel='AREA'>

# %% [markdown]
# We can see that more entries in the dataset.

# %% [markdown]
# ## PRT_ID

# %% [markdown]
# Since this is a suprivised problem and no need of primary key or id sort of features we are droping the 'PRT_ID'.

# %%
df.drop(['PRT_ID'],axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['AREA', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE'],
#       dtype='object')

# %% [markdown]
# ## DATE_SALE

# %% [markdown]
# Converting 'DATE_SALE' to Datetime format for later usage.

# %%
df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# Out:
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '19-12-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '13-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '13-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-06-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '19-10-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '16-02-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '25-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '19-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '13-12-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '23-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '13-05-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '19-07-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '19-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '18-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '15-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '26-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '28-04-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-11-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '23-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '28-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '24-01-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '18-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '23-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '18-11-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-05-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '26-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '23-10-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '20-04-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '28-09-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '30-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '14-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-07-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-12-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '31-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '20-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '13-06-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '19-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-07-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '18-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '30-07-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '16-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '30-07-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '30-03-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '19-01-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '13-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '20-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '23-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '24-10-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '24-10-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '26-07-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '17-10-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '26-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '24-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '30-05-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '20-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '26-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '15-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-02-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '25-09-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '23-07-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '27-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '29-01-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '14-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '20-06-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '23-11-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '28-02-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '20-12-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '19-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '30-10-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '17-10-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '29-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '30-04-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '16-12-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '26-10-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '19-05-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '24-10-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '28-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '27-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '25-01-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '17-12-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '17-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '26-03-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '24-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '28-05-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '24-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '27-06-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '27-05-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '17-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-10-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '29-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '25-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '17-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '15-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '24-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '16-06-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '29-03-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '18-10-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '18-11-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '25-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '13-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '26-01-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '25-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '18-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '16-05-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '27-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '24-10-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '25-10-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '18-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '17-12-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '24-04-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '26-06-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '16-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '27-06-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '15-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '25-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '14-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '29-05-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '23-01-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '14-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '14-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '13-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '27-09-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '29-10-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '29-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '31-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '17-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '17-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-12-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-04-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '17-12-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '20-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '16-08-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '18-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '16-01-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-04-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '30-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '31-01-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '15-01-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-04-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '15-09-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '15-09-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '23-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '27-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '29-08-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '29-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '26-09-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '17-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '26-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '20-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '25-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '13-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '23-12-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '20-09-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-06-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '15-04-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '16-04-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '24-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '16-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-11-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '16-10-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-09-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '19-01-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '20-04-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '13-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '19-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '25-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '31-01-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '30-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '14-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '27-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '25-07-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '31-01-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '25-01-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '15-09-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '15-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '24-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '26-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# ...
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '28-07-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '23-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '24-03-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '31-12-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '31-07-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '25-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '29-10-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '18-02-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '28-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '20-02-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '25-07-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '20-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '24-11-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '19-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '13-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '18-10-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '29-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '23-01-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '13-07-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '18-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '24-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '20-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '19-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '31-01-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '28-05-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '14-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '28-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '28-08-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '18-12-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '19-11-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-08-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '30-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '30-10-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '14-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '30-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '15-03-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '23-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '30-08-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '18-11-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '27-10-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '21-11-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '20-02-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '16-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '23-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '16-02-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '28-12-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '25-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '17-04-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '27-02-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '18-04-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-03-2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '16-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '22-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '24-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '15-11-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '28-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '25-08-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])
# C:\Users\haris\AppData\Local\Temp\ipykernel_10188\2258718761.py:1: UserWarning: Parsing '13-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])

# %%
df['DATE_SALE'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ## DATE_BUILD

# %% [markdown]
# Converting 'DATE_BUILD' to Datetime format for later usage.

# %%
df['DATE_SALE'] = pd.to_datetime(df['DATE_SALE'])

# %%
df['DATE_SALE'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ## SALE_COND

# %%
df.SALE_COND.unique()
# Out:
# array(['AbNormal', 'Family', 'Partial', 'AdjLand', 'Normal Sale',
#        'Ab Normal', 'Partiall', 'Adj Land', 'PartiaLl'], dtype=object)

# %% [markdown]
# We can see that there are some spelling mistakes in the given column

# %%
df['SALE_COND']=df['SALE_COND'].replace(['Partiall','PartiaLl'],'Partial')

# %%
df['SALE_COND'] = df['SALE_COND'].str.replace(" ","")

# %%
df.SALE_COND.unique()
# Out:
# array(['AbNormal', 'Family', 'Partial', 'AdjLand', 'NormalSale'],
#       dtype=object)

# %%
df.groupby('SALE_COND')['SALES_PRICE'].mean().sort_values(ascending=True).plot.bar()
# Out:
# <AxesSubplot:xlabel='SALE_COND'>

# %% [markdown]
# ## PARK_FACIL

# %%
df['PARK_FACIL'].unique()
# Out:
# array(['Yes', 'No', 'Noo'], dtype=object)

# %%
df.PARK_FACIL=df.PARK_FACIL.replace('Noo','No')

# %%
df.groupby('PARK_FACIL')['SALES_PRICE'].mean().sort_values(ascending=True).plot.bar()
# Out:
# <AxesSubplot:xlabel='PARK_FACIL'>

# %% [markdown]
# There is a highchance for sales to if there is a parking facility.

# %% [markdown]
# ## BUILDTYPE

# %%
df['BUILDTYPE'].unique()
# Out:
# array(['Commercial', 'Others', 'Other', 'House', 'Comercial'],
#       dtype=object)

# %% [markdown]
# We can see that there are some spelling mistake

# %%
df['BUILDTYPE']=df['BUILDTYPE'].replace({'Comercial':'Commercial','Other':'Others'})

# %%
df['BUILDTYPE'].unique()
# Out:
# array(['Commercial', 'Others', 'House'], dtype=object)

# %%
df.groupby('BUILDTYPE')['SALES_PRICE'].mean().sort_values(ascending=True).plot.bar()
# Out:
# <AxesSubplot:xlabel='BUILDTYPE'>

# %% [markdown]
# we can see that commercial type of houses solded more than Others and House on averages.

# %% [markdown]
# ## UTILITY_AVAL

# %%
df['UTILITY_AVAIL'].unique()
# Out:
# array(['AllPub', 'ELO', 'NoSewr ', 'NoSeWa', 'All Pub'], dtype=object)

# %% [markdown]
# We can see that there is a spelling mistake in the inputs of the column.

# %%
df['UTILITY_AVAIL'] = df['UTILITY_AVAIL'].replace('AllPub','All Pub')

# %%
df['UTILITY_AVAIL'].unique()
# Out:
# array(['All Pub', 'ELO', 'NoSewr ', 'NoSeWa'], dtype=object)

# %%
df.groupby('UTILITY_AVAIL')['SALES_PRICE'].mean().sort_values(ascending=True).plot.bar()
# Out:
# <AxesSubplot:xlabel='UTILITY_AVAIL'>

# %% [markdown]
# ## STREET

# %%
df['STREET'].unique()
# Out:
# array(['Paved', 'Gravel', 'No Access', 'Pavd', 'NoAccess'], dtype=object)

# %% [markdown]
# We can see that there is some spelling mistake in the inputs of the column

# %%
df['STREET']=df['STREET'].str.replace(' ','')
df['STREET']=df['STREET'].replace('Pavd','Paved')

# %%
df['STREET'].unique()
# Out:
# array(['Paved', 'Gravel', 'NoAccess'], dtype=object)

# %%
df.groupby('STREET')['SALES_PRICE'].mean().sort_values(ascending=True).plot.bar()
# Out:
# <AxesSubplot:xlabel='STREET'>

# %% [markdown]
# ## MZZONE

# %%
df['MZZONE'].unique()
# Out:
# array(['A', 'RH', 'RL', 'I', 'C', 'RM'], dtype=object)

# %% [markdown]
# Here there are no spelling mistakes,
# A - Agricultural
# I - Industrial
# C - Commercial
# RH - Resident High
# RL - Resident Low
# RM - Resident Medium

# %%
df.groupby('MZZONE')['SALES_PRICE'].mean().sort_values(ascending=True).plot.bar()
# Out:
# <AxesSubplot:xlabel='MZZONE'>

# %% [markdown]
# # NUMERICAL COLUMNS

# %% [markdown]
# ## INT_SQFT

# %%
df['INT_SQFT'].describe()
# Out:
# count    7109.000000
# mean     1382.073006
# std       457.410902
# min       500.000000
# 25%       993.000000
# 50%      1373.000000
# 75%      1744.000000
# max      2500.000000
# Name: INT_SQFT, dtype: float64

# %%
sns.boxplot(df['INT_SQFT'])
# Out:
# c:\Users\haris\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='INT_SQFT'>

# %% [markdown]
# From the above plot we can say that there are no outliers in the given data.

# %% [markdown]
# ## DIST_MAINROAD

# %%
df['DIST_MAINROAD'].describe()
# Out:
# count    7109.000000
# mean       99.603179
# std        57.403110
# min         0.000000
# 25%        50.000000
# 50%        99.000000
# 75%       148.000000
# max       200.000000
# Name: DIST_MAINROAD, dtype: float64

# %%
sns.boxplot(df['DIST_MAINROAD'])
# Out:
# c:\Users\haris\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DIST_MAINROAD'>

# %% [markdown]
# From the above plot we can say that there are no outliers in the given data.

# %% [markdown]
# ## N_BEDROOM

# %%
df['N_BEDROOM'].describe()
# Out:
# count    7108.000000
# mean        1.637029
# std         0.802902
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         4.000000
# Name: N_BEDROOM, dtype: float64

# %%
df['N_BEDROOM'].isnull().value_counts()
# Out:
# False    7108
# True        1
# Name: N_BEDROOM, dtype: int64

# %%
df['N_BEDROOM']=df['N_BEDROOM'].fillna(1)

# %%
df['N_BEDROOM'].isnull().value_counts()
# Out:
# False    7109
# Name: N_BEDROOM, dtype: int64

# %%
df['N_BEDROOM']=df['N_BEDROOM'].astype(int)
df['N_BEDROOM'].dtypes
# Out:
# dtype('int32')

# %%
df['N_BEDROOM'].describe()
# Out:
# count    7109.000000
# mean        1.636939
# std         0.802881
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         4.000000
# Name: N_BEDROOM, dtype: float64

# %%
sns.boxplot(df['DIST_MAINROAD'])
# Out:
# c:\Users\haris\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DIST_MAINROAD'>

# %% [markdown]
# Ther are not outliers in the given dataset

# %%
df.groupby('N_BEDROOM')['SALES_PRICE'].mean().sort_values(ascending=True).plot.bar()
# Out:
# <AxesSubplot:xlabel='N_BEDROOM'>

# %% [markdown]
# ## N_BATHROOM

# %%
df.N_BATHROOM.isnull().value_counts()
# Out:
# False    7104
# True        5
# Name: N_BATHROOM, dtype: int64

# %% [markdown]
# There are Five nulls.

# %%
df['N_BATHROOM']=df['N_BATHROOM'].fillna(df.groupby('QS_BATHROOM')['N_BATHROOM'].transform('median'))

# %%
df.N_BATHROOM.isnull().value_counts()
# Out:
# False    7109
# Name: N_BATHROOM, dtype: int64

# %% [markdown]
# Filled the null values with the median of QS_BATHROOM.

# %%
df['N_BATHROOM']=df['N_BATHROOM'].astype(int)
df['N_BATHROOM'].dtypes
# Out:
# dtype('int32')

# %%
df['N_BATHROOM'].describe()
# Out:
# count    7109.000000
# mean        1.213110
# std         0.409534
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         2.000000
# Name: N_BATHROOM, dtype: float64

# %% [markdown]
# THERE ARE NO OUTLIERS.

# %%
df['N_BATHROOM'].unique()
# Out:
# array([1, 2])

# %%
df.groupby('N_BATHROOM')['SALES_PRICE'].mean().sort_values(ascending=True).plot.bar()
# Out:
# <AxesSubplot:xlabel='N_BATHROOM'>

# %% [markdown]
# ## N_ROOM

# %%
df['N_ROOM'].isnull().value_counts()
# Out:
# False    7109
# Name: N_ROOM, dtype: int64

# %%
df['N_ROOM'].describe()
# Out:
# count    7109.000000
# mean        3.688704
# std         1.019099
# min         2.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         6.000000
# Name: N_ROOM, dtype: float64

# %%
df['N_ROOM'].unique()
# Out:
# array([3, 5, 4, 2, 6], dtype=int64)

# %%
df.groupby('N_ROOM')['SALES_PRICE'].mean().sort_values(ascending=True).plot.bar()
# Out:
# <AxesSubplot:xlabel='N_ROOM'>

# %%
df.columns
# Out:
# Index(['AREA', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE'],
#       dtype='object')

# %%
df
# Out:
#             AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 0     Karapakkam      1004 2011-04-05            131          1           1
# 1     Anna Nagar      1986 2006-12-19             26          2           1
# 2          Adyar       909 2012-04-02             70          1           1
# 3      Velachery      1855 2010-03-13             14          3           2
# 4     Karapakkam      1226 2009-05-10             84          1           1
# ...          ...       ...        ...            ...        ...         ...
# 7104  Karapakkam       598 2011-03-01             51          1           1
# 7105   Velachery      1897 2004-08-04             52          3           2
# 7106   Velachery      1614 2006-08-25            152          2           1
# 7107  Karapakkam       787 2009-03-08             40          1           1
# 7108   Velachery      1896 2005-07-13            156          3           2
#
#       N_ROOM   SALE_COND PARK_FACIL  DATE_BUILD  ... UTILITY_AVAIL    STREET  \
# 0          3    AbNormal        Yes  15-05-1967  ...       All Pub     Paved
# 1          5    AbNormal         No  22-12-1995  ...       All Pub    Gravel
# 2          3    AbNormal        Yes  09-02-1992  ...           ELO    Gravel
# 3          5      Family         No  18-03-1988  ...       NoSewr      Paved
# 4          3    AbNormal        Yes  13-10-1979  ...       All Pub    Gravel
# ...      ...         ...        ...         ...  ...           ...       ...
# 7104       2     AdjLand         No  15-01-1962  ...           ELO  NoAccess
# 7105       5      Family        Yes  11-04-1995  ...        NoSeWa  NoAccess
# 7106       4  NormalSale         No  01-09-1978  ...        NoSeWa    Gravel
# 7107       2     Partial        Yes  11-08-1977  ...           ELO     Paved
# 7108       5     Partial        Yes  24-07-1961  ...           ELO     Paved
#
#      MZZONE QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  \
# 0         A      4.0          3.9         4.9       4.330   380000  144400
# 1        RH      4.9          4.2         2.5       3.765   760122  304049
# 2        RL      4.1          3.8         2.2       3.090   421094   92114
# 3         I      4.7          3.9         3.6       4.010   356321   77042
# 4         C      3.0          2.5         4.1       3.290   237000   74063
# ...     ...      ...          ...         ...         ...      ...     ...
# 7104     RM      3.0          2.2         2.4       2.520   208767  107060
# 7105     RH      3.6          4.5         3.3       3.920   346191  205551
# 7106      I      4.3          4.2         2.9       3.840   317354  167028
# 7107     RL      4.6          3.8         4.1       4.160   425350  119098
# 7108      I      3.1          3.5         4.3       3.640   349177   79812
#
#       SALES_PRICE
# 0         7600000
# 1        21717770
# 2        13159200
# 3         9630290
# 4         7406250
# ...           ...
# 7104      5353000
# 7105     10818480
# 7106      8351410
# 7107      8507000
# 7108      9976480
#
# [7109 rows x 21 columns]

# %% [markdown]
# ## QS_ROOMS

# %%
df['QS_ROOMS'].isnull().value_counts()
# Out:
# False    7109
# Name: QS_ROOMS, dtype: int64

# %% [markdown]
# We can see that there are no nulls

# %%
df['QS_ROOMS'].describe()
# Out:
# count    7109.000000
# mean        3.517471
# std         0.891972
# min         2.000000
# 25%         2.700000
# 50%         3.500000
# 75%         4.300000
# max         5.000000
# Name: QS_ROOMS, dtype: float64

# %% [markdown]
# From the description itself we can see there are no outliers.

# %%
sns.boxplot(df['QS_ROOMS'])
# Out:
# c:\Users\haris\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='QS_ROOMS'>

# %% [markdown]
# ## QS_BATHROOM

# %%
df['QS_BATHROOM'].isnull().value_counts()
# Out:
# False    7109
# Name: QS_BATHROOM, dtype: int64

# %%
df['QS_BATHROOM'].nunique()
# Out:
# 31

# %% [markdown]
# we can see there are 31 unique values.

# %%
sns.boxplot(df['QS_BATHROOM'])
# Out:
# c:\Users\haris\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='QS_BATHROOM'>

# %% [markdown]
# ## QS_BEDROOM

# %%
df['QS_BEDROOM'].isnull().value_counts()
# Out:
# False    7109
# Name: QS_BEDROOM, dtype: int64

# %%
df['QS_BEDROOM'].nunique()
# Out:
# 31

# %%
sns.boxplot(df['QS_BEDROOM'])
# Out:
# c:\Users\haris\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='QS_BEDROOM'>
